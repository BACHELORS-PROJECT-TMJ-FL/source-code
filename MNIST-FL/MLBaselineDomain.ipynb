# %% [markdown]
# # Load dataset

# %%
from flwr_datasets.partitioner import IidPartitioner
from torch.utils.data import DataLoader
import datasets
import pandas as pd
import numpy as np
from PIL import Image


class ClinicPartitioner(IidPartitioner):
    """Partitioner for splitting MNIST into 5 centers."""

    def __init__(self):
        super().__init__(num_partitions=5)

    def load_partition(self, partition_id: int) -> datasets.Dataset:
        """
        Creates 5 partitions of the dataset:
            1. 0's and 1's
            2. 2's and 3's
            3. 4's and 5's
            4. 6's and 7's
            5. 8's and 9's
        """

        # Return the entire dataset if partition_id is -1
        if (partition_id == -1):
            return self.dataset

        df = pd.DataFrame(
            {
                "image": [np.array(img) for img in self.dataset["image"]],
                "label": self.dataset["label"],
            }
        )

        df1 = df[df["label"].isin([0, 1])]
        df2 = df[df["label"].isin([2, 3])]
        df3 = df[df["label"].isin([4, 5])]
        df4 = df[df["label"].isin([6, 7])]
        df5 = df[df["label"].isin([8, 9])]

        def convertPDtoDS(df):
            return datasets.Dataset.from_dict({
                "image": [Image.fromarray(np.array(img)) for img in df["image"]],
                "label": df["label"],
            })

        splitDataset = [
            convertPDtoDS(df1),
            convertPDtoDS(df2),
            convertPDtoDS(df3),
            convertPDtoDS(df4),
            convertPDtoDS(df5),
        ]

        return splitDataset[partition_id]


trainPartitioner = None
testPartitioner = None


def load_data(partition_id: int, split: int):
    """Load partition MNIST data."""
    # Only initialize `FederatedDataset` once
    global trainPartitioner, testPartitioner
    if trainPartitioner is None or testPartitioner is None:
        trainPartitioner = ClinicPartitioner()
        testPartitioner = ClinicPartitioner()
        ds = datasets.load_dataset(path="ylecun/mnist")
        ds = datasets.concatenate_datasets([ds["train"], ds["test"]])
        trainPartitioner.dataset = datasets.concatenate_datasets([ds.shard(5, i) for i in list(filter(lambda x: x != split, range(5)))])
        testPartitioner.dataset = ds.shard(5, split)
    partition_train = trainPartitioner.load_partition(partition_id)
    partition_test = testPartitioner.load_partition(partition_id)

    def apply_transforms(batch):
        """Apply transforms to the partition from FederatedDataset."""
        batch["image"] = [(np.array(img, dtype=np.float32) / 256).flatten() for img in batch["image"]] # Transform images to float and normalize
        return batch


    partition_train = partition_train.with_transform(apply_transforms)
    partition_test = partition_test.with_transform(apply_transforms)
    trainloader = DataLoader(partition_train, batch_size=32, shuffle=True)
    testloader = DataLoader(partition_test, batch_size=32)
    return trainloader, testloader

# %% [markdown]
# # Get model

# %%
from experiment3ERAGEM.task import get_net_train_test

Net, _, train, test = get_net_train_test(ILVariant="Domain")
# Out:
# 2025-05-30 15:23:40,905	INFO util.py:154 -- Missing packages: ['ipywidgets']. Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.

# %% [markdown]
# # Train and test model

# %%
accuracies_global_fold = []
accuracies_01_fold = []
accuracies_23_fold = []
accuracies_45_fold = []
accuracies_67_fold = []
accuracies_89_fold = []
for i in range(5):
    net = Net()

    trainloader_global, testloader_global = load_data(-1, i)
    _, testloader01 = load_data(0, i)
    _, testloader23 = load_data(1, i)
    _, testloader45 = load_data(2, i)
    _, testloader67 = load_data(3, i)
    _, testloader89 = load_data(4, i)
    print(f"Loaded data for fold {i}")

    accuracies_global  = []
    accuracies_01 = []
    accuracies_23 = []
    accuracies_45 = []
    accuracies_67 = []
    accuracies_89 = []

    # Get initial performance
    loss, accuracy_global, _, _, _ = test(net, testloader_global, "cpu")
    loss01, accuracy01, _, _, _ = test(net, testloader01, "cpu")
    loss23, accuracy23, _, _, _ = test(net, testloader23, "cpu")
    loss45, accuracy45, _, _, _ = test(net, testloader45, "cpu")
    loss67, accuracy67, _, _, _ = test(net, testloader67, "cpu")
    loss89, accuracy89, _, _, _ = test(net, testloader89, "cpu")
    accuracies_global.append(accuracy_global)
    accuracies_01.append(accuracy01)
    accuracies_23.append(accuracy23)
    accuracies_45.append(accuracy45)
    accuracies_67.append(accuracy67)
    accuracies_89.append(accuracy89)

    epocs = 50
    for i in range(epocs):
        print(f"Epoch {i+1}/{epocs}")
        # Train the model
        train_loss = train(net, trainloader_global, None, "cpu")

        loss, accuracy_global, _, _, _ = test(net, testloader_global, "cpu")
        loss01, accuracy01, _, _, _ = test(net, testloader01, "cpu")
        loss23, accuracy23, _, _, _ = test(net, testloader23, "cpu")
        loss45, accuracy45, _, _, _ = test(net, testloader45, "cpu")
        loss67, accuracy67, _, _, _ = test(net, testloader67, "cpu")
        loss89, accuracy89, _, _, _ = test(net, testloader89, "cpu")
        print(f"Epoch {i+1}/{epocs}, train_loss: {train_loss:.4f}, test_accuracy: {accuracy_global:.4f}")
        accuracies_global.append(accuracy_global)
        accuracies_01.append(accuracy01)
        accuracies_23.append(accuracy23)
        accuracies_45.append(accuracy45)
        accuracies_67.append(accuracy67)
        accuracies_89.append(accuracy89)
    accuracies_global_fold.append(accuracies_global)
    accuracies_01_fold.append(accuracies_01)
    accuracies_23_fold.append(accuracies_23)
    accuracies_45_fold.append(accuracies_45)
    accuracies_67_fold.append(accuracies_67)
    accuracies_89_fold.append(accuracies_89)
# Out:
# Loaded data for fold 0
# Epoch 1/50
# Epoch 1/50, train_loss: 0.3422, test_accuracy: 0.9091
# Epoch 2/50
# Epoch 2/50, train_loss: 0.1962, test_accuracy: 0.9444
# Epoch 3/50
# Epoch 3/50, train_loss: 0.1438, test_accuracy: 0.9557
# Epoch 4/50
# Epoch 4/50, train_loss: 0.1172, test_accuracy: 0.9610
# Epoch 5/50
# Epoch 5/50, train_loss: 0.1021, test_accuracy: 0.9649
# Epoch 6/50
# Epoch 6/50, train_loss: 0.0915, test_accuracy: 0.9674
# Epoch 7/50
# Epoch 7/50, train_loss: 0.0838, test_accuracy: 0.9696
# Epoch 8/50
# Epoch 8/50, train_loss: 0.0770, test_accuracy: 0.9711
# Epoch 9/50
# Epoch 9/50, train_loss: 0.0720, test_accuracy: 0.9726
# Epoch 10/50
# Epoch 10/50, train_loss: 0.0673, test_accuracy: 0.9731
# Epoch 11/50
# Epoch 11/50, train_loss: 0.0634, test_accuracy: 0.9740
# Epoch 12/50
# Epoch 12/50, train_loss: 0.0600, test_accuracy: 0.9731
# Epoch 13/50
# Epoch 13/50, train_loss: 0.0568, test_accuracy: 0.9750
# Epoch 14/50
# Epoch 14/50, train_loss: 0.0543, test_accuracy: 0.9754
# Epoch 15/50
# Epoch 15/50, train_loss: 0.0517, test_accuracy: 0.9754
# Epoch 16/50
# Epoch 16/50, train_loss: 0.0491, test_accuracy: 0.9771
# Epoch 17/50
# Epoch 17/50, train_loss: 0.0466, test_accuracy: 0.9776
# Epoch 18/50
# Epoch 18/50, train_loss: 0.0450, test_accuracy: 0.9782
# Epoch 19/50
# Epoch 19/50, train_loss: 0.0430, test_accuracy: 0.9775
# Epoch 20/50
# Epoch 20/50, train_loss: 0.0412, test_accuracy: 0.9781
# Epoch 21/50
# Epoch 21/50, train_loss: 0.0398, test_accuracy: 0.9786
# Epoch 22/50
# Epoch 22/50, train_loss: 0.0381, test_accuracy: 0.9786
# Epoch 23/50
# Epoch 23/50, train_loss: 0.0369, test_accuracy: 0.9789
# Epoch 24/50
# Epoch 24/50, train_loss: 0.0354, test_accuracy: 0.9789
# Epoch 25/50
# Epoch 25/50, train_loss: 0.0342, test_accuracy: 0.9796
# Epoch 26/50
# Epoch 26/50, train_loss: 0.0328, test_accuracy: 0.9791
# Epoch 27/50
# Epoch 27/50, train_loss: 0.0315, test_accuracy: 0.9799
# Epoch 28/50
# Epoch 28/50, train_loss: 0.0305, test_accuracy: 0.9800
# Epoch 29/50
# Epoch 29/50, train_loss: 0.0292, test_accuracy: 0.9801
# Epoch 30/50
# Epoch 30/50, train_loss: 0.0281, test_accuracy: 0.9795
# Epoch 31/50
# Epoch 31/50, train_loss: 0.0271, test_accuracy: 0.9805
# Epoch 32/50
# Epoch 32/50, train_loss: 0.0262, test_accuracy: 0.9802
# Epoch 33/50
# Epoch 33/50, train_loss: 0.0253, test_accuracy: 0.9801
# Epoch 34/50
# Epoch 34/50, train_loss: 0.0244, test_accuracy: 0.9813
# Epoch 35/50
# Epoch 35/50, train_loss: 0.0236, test_accuracy: 0.9788
# Epoch 36/50
# Epoch 36/50, train_loss: 0.0223, test_accuracy: 0.9800
# Epoch 37/50
# Epoch 37/50, train_loss: 0.0217, test_accuracy: 0.9803
# Epoch 38/50
# Epoch 38/50, train_loss: 0.0207, test_accuracy: 0.9786
# Epoch 39/50
# Epoch 39/50, train_loss: 0.0202, test_accuracy: 0.9807
# Epoch 40/50
# Epoch 40/50, train_loss: 0.0193, test_accuracy: 0.9806
# Epoch 41/50
# Epoch 41/50, train_loss: 0.0185, test_accuracy: 0.9806
# Epoch 42/50
# Epoch 42/50, train_loss: 0.0179, test_accuracy: 0.9803
# Epoch 43/50
# Epoch 43/50, train_loss: 0.0172, test_accuracy: 0.9791
# Epoch 44/50
# Epoch 44/50, train_loss: 0.0163, test_accuracy: 0.9801
# Epoch 45/50
# Epoch 45/50, train_loss: 0.0159, test_accuracy: 0.9801
# Epoch 46/50
# Epoch 46/50, train_loss: 0.0152, test_accuracy: 0.9819
# Epoch 47/50
# Epoch 47/50, train_loss: 0.0144, test_accuracy: 0.9808
# Epoch 48/50
# Epoch 48/50, train_loss: 0.0137, test_accuracy: 0.9809
# Epoch 49/50
# Epoch 49/50, train_loss: 0.0133, test_accuracy: 0.9804
# Epoch 50/50
# Epoch 50/50, train_loss: 0.0129, test_accuracy: 0.9809
# Loaded data for fold 1
# Epoch 1/50
# Epoch 1/50, train_loss: 0.3307, test_accuracy: 0.9169
# Epoch 2/50
# Epoch 2/50, train_loss: 0.1869, test_accuracy: 0.9431
# Epoch 3/50
# Epoch 3/50, train_loss: 0.1470, test_accuracy: 0.9539
# Epoch 4/50
# Epoch 4/50, train_loss: 0.1275, test_accuracy: 0.9588
# Epoch 5/50
# Epoch 5/50, train_loss: 0.1147, test_accuracy: 0.9619
# Epoch 6/50
# Epoch 6/50, train_loss: 0.1050, test_accuracy: 0.9649
# Epoch 7/50
# Epoch 7/50, train_loss: 0.0975, test_accuracy: 0.9669
# Epoch 8/50
# Epoch 8/50, train_loss: 0.0911, test_accuracy: 0.9676
# Epoch 9/50
# Epoch 9/50, train_loss: 0.0858, test_accuracy: 0.9696
# Epoch 10/50
# Epoch 10/50, train_loss: 0.0810, test_accuracy: 0.9696
# Epoch 11/50
# Epoch 11/50, train_loss: 0.0770, test_accuracy: 0.9711
# Epoch 12/50
# Epoch 12/50, train_loss: 0.0730, test_accuracy: 0.9711
# Epoch 13/50
# Epoch 13/50, train_loss: 0.0696, test_accuracy: 0.9720
# Epoch 14/50
# Epoch 14/50, train_loss: 0.0664, test_accuracy: 0.9719
# Epoch 15/50
# Epoch 15/50, train_loss: 0.0635, test_accuracy: 0.9742
# Epoch 16/50
# Epoch 16/50, train_loss: 0.0607, test_accuracy: 0.9746
# Epoch 17/50
# Epoch 17/50, train_loss: 0.0582, test_accuracy: 0.9737
# Epoch 18/50
# Epoch 18/50, train_loss: 0.0554, test_accuracy: 0.9756
# Epoch 19/50
# Epoch 19/50, train_loss: 0.0535, test_accuracy: 0.9744
# Epoch 20/50
# Epoch 20/50, train_loss: 0.0515, test_accuracy: 0.9755
# Epoch 21/50
# Epoch 21/50, train_loss: 0.0492, test_accuracy: 0.9754
# Epoch 22/50
# Epoch 22/50, train_loss: 0.0478, test_accuracy: 0.9746
# Epoch 23/50
# Epoch 23/50, train_loss: 0.0458, test_accuracy: 0.9745
# Epoch 24/50
# Epoch 24/50, train_loss: 0.0442, test_accuracy: 0.9764
# Epoch 25/50
# Epoch 25/50, train_loss: 0.0428, test_accuracy: 0.9741
# Epoch 26/50
# Epoch 26/50, train_loss: 0.0413, test_accuracy: 0.9766
# Epoch 27/50
# Epoch 27/50, train_loss: 0.0405, test_accuracy: 0.9764
# Epoch 28/50
# Epoch 28/50, train_loss: 0.0390, test_accuracy: 0.9757
# Epoch 29/50
# Epoch 29/50, train_loss: 0.0377, test_accuracy: 0.9763
# Epoch 30/50
# Epoch 30/50, train_loss: 0.0373, test_accuracy: 0.9756
# Epoch 31/50
# Epoch 31/50, train_loss: 0.0360, test_accuracy: 0.9766
# Epoch 32/50
# Epoch 32/50, train_loss: 0.0352, test_accuracy: 0.9774
# Epoch 33/50
# Epoch 33/50, train_loss: 0.0341, test_accuracy: 0.9767
# Epoch 34/50
# Epoch 34/50, train_loss: 0.0332, test_accuracy: 0.9777
# Epoch 35/50
# Epoch 35/50, train_loss: 0.0327, test_accuracy: 0.9778
# Epoch 36/50
# Epoch 36/50, train_loss: 0.0315, test_accuracy: 0.9767
# Epoch 37/50
# Epoch 37/50, train_loss: 0.0309, test_accuracy: 0.9776
# Epoch 38/50
# Epoch 38/50, train_loss: 0.0300, test_accuracy: 0.9775
# Epoch 39/50
# Epoch 39/50, train_loss: 0.0295, test_accuracy: 0.9765
# Epoch 40/50
# Epoch 40/50, train_loss: 0.0290, test_accuracy: 0.9771
# Epoch 41/50
# Epoch 41/50, train_loss: 0.0282, test_accuracy: 0.9771
# Epoch 42/50
# Epoch 42/50, train_loss: 0.0277, test_accuracy: 0.9776
# Epoch 43/50
# Epoch 43/50, train_loss: 0.0267, test_accuracy: 0.9777
# Epoch 44/50
# Epoch 44/50, train_loss: 0.0264, test_accuracy: 0.9775
# Epoch 45/50
# Epoch 45/50, train_loss: 0.0258, test_accuracy: 0.9749
# Epoch 46/50
# Epoch 46/50, train_loss: 0.0253, test_accuracy: 0.9771
# Epoch 47/50
# Epoch 47/50, train_loss: 0.0244, test_accuracy: 0.9774
# Epoch 48/50
# Epoch 48/50, train_loss: 0.0242, test_accuracy: 0.9779
# Epoch 49/50
# Epoch 49/50, train_loss: 0.0233, test_accuracy: 0.9776
# Epoch 50/50
# Epoch 50/50, train_loss: 0.0228, test_accuracy: 0.9772
# Loaded data for fold 2
# Epoch 1/50
# Epoch 1/50, train_loss: 0.3355, test_accuracy: 0.9044
# Epoch 2/50
# Epoch 2/50, train_loss: 0.2046, test_accuracy: 0.9389
# Epoch 3/50
# Epoch 3/50, train_loss: 0.1560, test_accuracy: 0.9527
# Epoch 4/50
# Epoch 4/50, train_loss: 0.1299, test_accuracy: 0.9576
# Epoch 5/50
# Epoch 5/50, train_loss: 0.1134, test_accuracy: 0.9610
# Epoch 6/50
# Epoch 6/50, train_loss: 0.1015, test_accuracy: 0.9644
# Epoch 7/50
# Epoch 7/50, train_loss: 0.0916, test_accuracy: 0.9680
# Epoch 8/50
# Epoch 8/50, train_loss: 0.0837, test_accuracy: 0.9687
# Epoch 9/50
# Epoch 9/50, train_loss: 0.0770, test_accuracy: 0.9697
# Epoch 10/50
# Epoch 10/50, train_loss: 0.0716, test_accuracy: 0.9725
# Epoch 11/50
# Epoch 11/50, train_loss: 0.0666, test_accuracy: 0.9734
# Epoch 12/50
# Epoch 12/50, train_loss: 0.0624, test_accuracy: 0.9749
# Epoch 13/50
# Epoch 13/50, train_loss: 0.0586, test_accuracy: 0.9759
# Epoch 14/50
# Epoch 14/50, train_loss: 0.0554, test_accuracy: 0.9763
# Epoch 15/50
# Epoch 15/50, train_loss: 0.0523, test_accuracy: 0.9774
# Epoch 16/50
# Epoch 16/50, train_loss: 0.0496, test_accuracy: 0.9766
# Epoch 17/50
# Epoch 17/50, train_loss: 0.0474, test_accuracy: 0.9775
# Epoch 18/50
# Epoch 18/50, train_loss: 0.0453, test_accuracy: 0.9775
# Epoch 19/50
# Epoch 19/50, train_loss: 0.0432, test_accuracy: 0.9788
# Epoch 20/50
# Epoch 20/50, train_loss: 0.0415, test_accuracy: 0.9774
# Epoch 21/50
# Epoch 21/50, train_loss: 0.0395, test_accuracy: 0.9780
# Epoch 22/50
# Epoch 22/50, train_loss: 0.0383, test_accuracy: 0.9784
# Epoch 23/50
# Epoch 23/50, train_loss: 0.0366, test_accuracy: 0.9799
# Epoch 24/50
# Epoch 24/50, train_loss: 0.0350, test_accuracy: 0.9788
# Epoch 25/50
# Epoch 25/50, train_loss: 0.0340, test_accuracy: 0.9799
# Epoch 26/50
# Epoch 26/50, train_loss: 0.0323, test_accuracy: 0.9785
# Epoch 27/50
# Epoch 27/50, train_loss: 0.0314, test_accuracy: 0.9790
# Epoch 28/50
# Epoch 28/50, train_loss: 0.0300, test_accuracy: 0.9791
# Epoch 29/50
# Epoch 29/50, train_loss: 0.0289, test_accuracy: 0.9797
# Epoch 30/50
# Epoch 30/50, train_loss: 0.0281, test_accuracy: 0.9796
# Epoch 31/50
# Epoch 31/50, train_loss: 0.0269, test_accuracy: 0.9789
# Epoch 32/50
# Epoch 32/50, train_loss: 0.0258, test_accuracy: 0.9791
# Epoch 33/50
# Epoch 33/50, train_loss: 0.0250, test_accuracy: 0.9790
# Epoch 34/50
# Epoch 34/50, train_loss: 0.0241, test_accuracy: 0.9789
# Epoch 35/50
# Epoch 35/50, train_loss: 0.0232, test_accuracy: 0.9804
# Epoch 36/50
# Epoch 36/50, train_loss: 0.0225, test_accuracy: 0.9789
# Epoch 37/50
# Epoch 37/50, train_loss: 0.0217, test_accuracy: 0.9801
# Epoch 38/50
# Epoch 38/50, train_loss: 0.0209, test_accuracy: 0.9799
# Epoch 39/50
# Epoch 39/50, train_loss: 0.0203, test_accuracy: 0.9789
# Epoch 40/50
# Epoch 40/50, train_loss: 0.0196, test_accuracy: 0.9800
# Epoch 41/50
# Epoch 41/50, train_loss: 0.0189, test_accuracy: 0.9787
# Epoch 42/50
# Epoch 42/50, train_loss: 0.0179, test_accuracy: 0.9799
# Epoch 43/50
# Epoch 43/50, train_loss: 0.0173, test_accuracy: 0.9789
# Epoch 44/50
# Epoch 44/50, train_loss: 0.0165, test_accuracy: 0.9787
# Epoch 45/50
# Epoch 45/50, train_loss: 0.0160, test_accuracy: 0.9778
# Epoch 46/50
# Epoch 46/50, train_loss: 0.0153, test_accuracy: 0.9786
# Epoch 47/50
# Epoch 47/50, train_loss: 0.0147, test_accuracy: 0.9789
# Epoch 48/50
# Epoch 48/50, train_loss: 0.0143, test_accuracy: 0.9804
# Epoch 49/50
# Epoch 49/50, train_loss: 0.0138, test_accuracy: 0.9801
# Epoch 50/50
# Epoch 50/50, train_loss: 0.0132, test_accuracy: 0.9796
# Loaded data for fold 3
# Epoch 1/50
# Epoch 1/50, train_loss: 0.3264, test_accuracy: 0.9124
# Epoch 2/50
# Epoch 2/50, train_loss: 0.1864, test_accuracy: 0.9451
# Epoch 3/50
# Epoch 3/50, train_loss: 0.1429, test_accuracy: 0.9556
# Epoch 4/50
# Epoch 4/50, train_loss: 0.1207, test_accuracy: 0.9593
# Epoch 5/50
# Epoch 5/50, train_loss: 0.1066, test_accuracy: 0.9627
# Epoch 6/50
# Epoch 6/50, train_loss: 0.0959, test_accuracy: 0.9663
# Epoch 7/50
# Epoch 7/50, train_loss: 0.0876, test_accuracy: 0.9682
# Epoch 8/50
# Epoch 8/50, train_loss: 0.0806, test_accuracy: 0.9699
# Epoch 9/50
# Epoch 9/50, train_loss: 0.0748, test_accuracy: 0.9710
# Epoch 10/50
# Epoch 10/50, train_loss: 0.0700, test_accuracy: 0.9710
# Epoch 11/50
# Epoch 11/50, train_loss: 0.0659, test_accuracy: 0.9720
# Epoch 12/50
# Epoch 12/50, train_loss: 0.0622, test_accuracy: 0.9724
# Epoch 13/50
# Epoch 13/50, train_loss: 0.0590, test_accuracy: 0.9736
# Epoch 14/50
# Epoch 14/50, train_loss: 0.0565, test_accuracy: 0.9746
# Epoch 15/50
# Epoch 15/50, train_loss: 0.0539, test_accuracy: 0.9743
# Epoch 16/50
# Epoch 16/50, train_loss: 0.0516, test_accuracy: 0.9763
# Epoch 17/50
# Epoch 17/50, train_loss: 0.0497, test_accuracy: 0.9760
# Epoch 18/50
# Epoch 18/50, train_loss: 0.0476, test_accuracy: 0.9754
# Epoch 19/50
# Epoch 19/50, train_loss: 0.0457, test_accuracy: 0.9757
# Epoch 20/50
# Epoch 20/50, train_loss: 0.0439, test_accuracy: 0.9774
# Epoch 21/50
# Epoch 21/50, train_loss: 0.0424, test_accuracy: 0.9779
# Epoch 22/50
# Epoch 22/50, train_loss: 0.0408, test_accuracy: 0.9771
# Epoch 23/50
# Epoch 23/50, train_loss: 0.0391, test_accuracy: 0.9773
# Epoch 24/50
# Epoch 24/50, train_loss: 0.0381, test_accuracy: 0.9767
# Epoch 25/50
# Epoch 25/50, train_loss: 0.0365, test_accuracy: 0.9771
# Epoch 26/50
# Epoch 26/50, train_loss: 0.0353, test_accuracy: 0.9770
# Epoch 27/50
# Epoch 27/50, train_loss: 0.0341, test_accuracy: 0.9775
# Epoch 28/50
# Epoch 28/50, train_loss: 0.0328, test_accuracy: 0.9767
# Epoch 29/50
# Epoch 29/50, train_loss: 0.0315, test_accuracy: 0.9782
# Epoch 30/50
# Epoch 30/50, train_loss: 0.0305, test_accuracy: 0.9786
# Epoch 31/50
# Epoch 31/50, train_loss: 0.0297, test_accuracy: 0.9782
# Epoch 32/50
# Epoch 32/50, train_loss: 0.0281, test_accuracy: 0.9790
# Epoch 33/50
# Epoch 33/50, train_loss: 0.0277, test_accuracy: 0.9780
# Epoch 34/50
# Epoch 34/50, train_loss: 0.0266, test_accuracy: 0.9786
# Epoch 35/50
# Epoch 35/50, train_loss: 0.0258, test_accuracy: 0.9793
# Epoch 36/50
# Epoch 36/50, train_loss: 0.0249, test_accuracy: 0.9786
# Epoch 37/50
# Epoch 37/50, train_loss: 0.0237, test_accuracy: 0.9784
# Epoch 38/50
# Epoch 38/50, train_loss: 0.0231, test_accuracy: 0.9785
# Epoch 39/50
# Epoch 39/50, train_loss: 0.0221, test_accuracy: 0.9788
# Epoch 40/50
# Epoch 40/50, train_loss: 0.0214, test_accuracy: 0.9785
# Epoch 41/50
# Epoch 41/50, train_loss: 0.0209, test_accuracy: 0.9796
# Epoch 42/50
# Epoch 42/50, train_loss: 0.0204, test_accuracy: 0.9799
# Epoch 43/50
# Epoch 43/50, train_loss: 0.0198, test_accuracy: 0.9797
# Epoch 44/50
# Epoch 44/50, train_loss: 0.0192, test_accuracy: 0.9788
# Epoch 45/50
# Epoch 45/50, train_loss: 0.0182, test_accuracy: 0.9788
# Epoch 46/50
# Epoch 46/50, train_loss: 0.0176, test_accuracy: 0.9791
# Epoch 47/50
# Epoch 47/50, train_loss: 0.0168, test_accuracy: 0.9790
# Epoch 48/50
# Epoch 48/50, train_loss: 0.0164, test_accuracy: 0.9791
# Epoch 49/50
# Epoch 49/50, train_loss: 0.0157, test_accuracy: 0.9789
# Epoch 50/50
# Epoch 50/50, train_loss: 0.0157, test_accuracy: 0.9795
# Loaded data for fold 4
# c:\Users\Bruger\Desktop\Bachelor-Project---Federated-Incremental-Learning\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Bruger\Desktop\Bachelor-Project---Federated-Incremental-Learning\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Bruger\Desktop\Bachelor-Project---Federated-Incremental-Learning\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Bruger\Desktop\Bachelor-Project---Federated-Incremental-Learning\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Bruger\Desktop\Bachelor-Project---Federated-Incremental-Learning\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\Bruger\Desktop\Bachelor-Project---Federated-Incremental-Learning\.venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Epoch 1/50
# Epoch 1/50, train_loss: 0.3436, test_accuracy: 0.9097
# Epoch 2/50
# Epoch 2/50, train_loss: 0.1943, test_accuracy: 0.9453
# Epoch 3/50
# Epoch 3/50, train_loss: 0.1432, test_accuracy: 0.9570
# Epoch 4/50
# Epoch 4/50, train_loss: 0.1197, test_accuracy: 0.9619
# Epoch 5/50
# Epoch 5/50, train_loss: 0.1047, test_accuracy: 0.9645
# Epoch 6/50
# Epoch 6/50, train_loss: 0.0942, test_accuracy: 0.9669
# Epoch 7/50
# Epoch 7/50, train_loss: 0.0855, test_accuracy: 0.9691
# Epoch 8/50
# Epoch 8/50, train_loss: 0.0789, test_accuracy: 0.9702
# Epoch 9/50
# Epoch 9/50, train_loss: 0.0735, test_accuracy: 0.9718
# Epoch 10/50
# Epoch 10/50, train_loss: 0.0682, test_accuracy: 0.9726
# Epoch 11/50
# Epoch 11/50, train_loss: 0.0637, test_accuracy: 0.9731
# Epoch 12/50
# Epoch 12/50, train_loss: 0.0600, test_accuracy: 0.9755
# Epoch 13/50
# Epoch 13/50, train_loss: 0.0564, test_accuracy: 0.9746
# Epoch 14/50
# Epoch 14/50, train_loss: 0.0537, test_accuracy: 0.9762
# Epoch 15/50
# Epoch 15/50, train_loss: 0.0507, test_accuracy: 0.9757
# Epoch 16/50
# Epoch 16/50, train_loss: 0.0483, test_accuracy: 0.9769
# Epoch 17/50
# Epoch 17/50, train_loss: 0.0463, test_accuracy: 0.9759
# Epoch 18/50
# Epoch 18/50, train_loss: 0.0443, test_accuracy: 0.9775
# Epoch 19/50
# Epoch 19/50, train_loss: 0.0425, test_accuracy: 0.9774
# Epoch 20/50
# Epoch 20/50, train_loss: 0.0407, test_accuracy: 0.9774
# Epoch 21/50
# Epoch 21/50, train_loss: 0.0392, test_accuracy: 0.9784
# Epoch 22/50
# Epoch 22/50, train_loss: 0.0376, test_accuracy: 0.9779
# Epoch 23/50
# Epoch 23/50, train_loss: 0.0362, test_accuracy: 0.9788
# Epoch 24/50
# Epoch 24/50, train_loss: 0.0352, test_accuracy: 0.9789
# Epoch 25/50
# Epoch 25/50, train_loss: 0.0335, test_accuracy: 0.9789
# Epoch 26/50
# Epoch 26/50, train_loss: 0.0326, test_accuracy: 0.9792
# Epoch 27/50
# Epoch 27/50, train_loss: 0.0315, test_accuracy: 0.9785
# Epoch 28/50
# Epoch 28/50, train_loss: 0.0304, test_accuracy: 0.9794
# Epoch 29/50
# Epoch 29/50, train_loss: 0.0293, test_accuracy: 0.9791
# Epoch 30/50
# Epoch 30/50, train_loss: 0.0284, test_accuracy: 0.9783
# Epoch 31/50
# Epoch 31/50, train_loss: 0.0273, test_accuracy: 0.9793
# Epoch 32/50
# Epoch 32/50, train_loss: 0.0263, test_accuracy: 0.9783
# Epoch 33/50
# Epoch 33/50, train_loss: 0.0255, test_accuracy: 0.9796
# Epoch 34/50
# Epoch 34/50, train_loss: 0.0245, test_accuracy: 0.9795
# Epoch 35/50
# Epoch 35/50, train_loss: 0.0236, test_accuracy: 0.9797
# Epoch 36/50
# Epoch 36/50, train_loss: 0.0228, test_accuracy: 0.9796
# Epoch 37/50
# Epoch 37/50, train_loss: 0.0221, test_accuracy: 0.9791
# Epoch 38/50
# Epoch 38/50, train_loss: 0.0214, test_accuracy: 0.9799
# Epoch 39/50
# Epoch 39/50, train_loss: 0.0207, test_accuracy: 0.9779
# Epoch 40/50
# Epoch 40/50, train_loss: 0.0199, test_accuracy: 0.9791
# Epoch 41/50
# Epoch 41/50, train_loss: 0.0191, test_accuracy: 0.9787
# Epoch 42/50
# Epoch 42/50, train_loss: 0.0187, test_accuracy: 0.9799
# Epoch 43/50
# Epoch 43/50, train_loss: 0.0183, test_accuracy: 0.9794
# Epoch 44/50
# Epoch 44/50, train_loss: 0.0175, test_accuracy: 0.9794
# Epoch 45/50
# Epoch 45/50, train_loss: 0.0168, test_accuracy: 0.9789
# Epoch 46/50
# Epoch 46/50, train_loss: 0.0163, test_accuracy: 0.9802
# Epoch 47/50
# Epoch 47/50, train_loss: 0.0157, test_accuracy: 0.9793
# Epoch 48/50
# Epoch 48/50, train_loss: 0.0149, test_accuracy: 0.9794
# Epoch 49/50
# Epoch 49/50, train_loss: 0.0144, test_accuracy: 0.9784
# Epoch 50/50
# Epoch 50/50, train_loss: 0.0139, test_accuracy: 0.9791

# %%
d_save = {
    "accuracies_global": accuracies_global_fold,
    "accuracies_01": accuracies_01_fold,
    "accuracies_23": accuracies_23_fold,
    "accuracies_45": accuracies_45_fold,
    "accuracies_67": accuracies_67_fold,
    "accuracies_89": accuracies_89_fold
}

import pickle
with open("accuracies_ML_domain.pkl", "wb") as f:
    pickle.dump(d_save, f)

# %%
import pickle

# Load the accuracies from the file
d_load = None
with open("accuracies_ML_domain.pkl", "rb") as f:
    d_load = pickle.load(f)

acc_global = np.array(d_load["accuracies_global"])
acc_01 = np.array(d_load["accuracies_01"])
acc_23 = np.array(d_load["accuracies_23"])
acc_45 = np.array(d_load["accuracies_45"])
acc_67 = np.array(d_load["accuracies_67"])
acc_89 = np.array(d_load["accuracies_89"])

# %%
def get_mean_std(acc):
    """Get mean and std of the accuracies."""
    return np.mean(acc, axis=0), np.std(acc, axis=0)

mean_global, std_global = get_mean_std(acc_global)
mean_01, std_01 = get_mean_std(acc_01)
mean_23, std_23 = get_mean_std(acc_23)
mean_45, std_45 = get_mean_std(acc_45)
mean_67, std_67 = get_mean_std(acc_67)
mean_89, std_89 = get_mean_std(acc_89)

# %%
def print_final_mean_std(mean, std, label):
    """Print the final mean and std of the accuracies."""
    print("acctstd{" + f"{mean:.3f}" +"}{" + f"{std:.3f}" +"}")
    # print(f"{label} - Mean: {mean:.4f}, Std: {std:.4f}")

print_final_mean_std(mean_global[-1], std_global[-1], "Global")
print_final_mean_std(mean_01[-1], std_01[-1], "0's and 1's")
print_final_mean_std(mean_23[-1], std_23[-1], "2's and 3's")
print_final_mean_std(mean_45[-1], std_45[-1], "4's and 5's")
print_final_mean_std(mean_67[-1], std_67[-1], "6's and 7's")
print_final_mean_std(mean_89[-1], std_89[-1], "8's and 9's")
# Out:
# acctstd{0.979}{0.001}
# acctstd{0.991}{0.001}
# acctstd{0.977}{0.003}
# acctstd{0.974}{0.001}
# acctstd{0.989}{0.001}
# acctstd{0.963}{0.003}

# %%
import matplotlib.pyplot as plt

class Plot:
    def __init__(self):
        self.fig, self.ax = plt.subplots()

    def plot_mean_std(self, mean_data: np.ndarray, std_data: np.ndarray, title: str = "", name: str = "", x_label: str = "Rounds", y_label: str = "Metric", show_end_value: bool = False, ylims=(0,1)):
            rounds = np.arange(len(mean_data))

            self.ax.plot(rounds, mean_data, label=f"{name}")
            self.ax.fill_between(
                rounds,
                mean_data - std_data,
                mean_data + std_data,
                alpha=0.1,
                # label=f"{name} (Standard Deviation)",
            )

            self.ax.set_xlabel(x_label, fontsize=axis_font_size)
            self.ax.set_ylabel("Accuracy", fontsize=axis_font_size)
            self.ax.set_title(title, fontsize=title_font_size)
            self.ax.set_ylim(ylims)
            self.ax.grid()
            
            # Show last value of mean_data on the plot
            # if show_end_value:
            #     self.ax.text(
            #         rounds[-1] + 5,
            #         mean_data[-1],
            #         f"{mean_data[-1]:.3f}",
            #         fontsize=10,
            #         verticalalignment="bottom",
            #         horizontalalignment="right",
            #         color="black",
            #         bbox=dict(facecolor="white", edgecolor="black", boxstyle="round,pad=0.3"),
            #     )

            self.ax.legend(fontsize=legend_font_size, loc="lower right")             

            return self.fig, self.ax

p = Plot()

fig, ax = p.plot_mean_std(mean_global, std_global, title="FDIL Global Accuracy", show_end_value=True, ylims=(0.6, 1))

fig.savefig("exp3_ML_global_accuracy_domain.svg", format="svg")
# Out:
# C:\Users\Bruger\AppData\Local\Temp\ipykernel_40152\3409675818.py:38: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   self.ax.legend(fontsize=legend_font_size, loc="lower right")

# %%
p = Plot()

p.plot_mean_std(mean_01, std_01, title="FDIL Client Domain Accuracy", name="accuracy_01")
p.plot_mean_std(mean_23, std_23, title="FDIL Client Domain Accuracy", name="accuracy_23")
p.plot_mean_std(mean_45, std_45, title="FDIL Client Domain Accuracy", name="accuracy_45")
p.plot_mean_std(mean_67, std_67, title="FDIL Client Domain Accuracy", name="accuracy_67")
fig, ax = p.plot_mean_std(mean_89, std_89, title="FDIL Client Domain Accuracy", name="accuracy_89")

fig.savefig("exp3_ML_domain_accuracy_domain.svg", format="svg")
